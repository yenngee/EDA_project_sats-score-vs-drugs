# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 15px; height: 80px">
#
# # Project 2
#
# ### Exploratory Data Analysis (EDA)
#
# ---
#
# Your hometown mayor just created a new data analysis team to give policy advice, and the administration recruited _you_ via LinkedIn to join it. Unfortunately, due to budget constraints, for now the "team" is just you...
#
# The mayor wants to start a new initiative to move the needle on one of two separate issues: high school education outcomes, or drug abuse in the community.
#
# Also unfortunately, that is the entirety of what you've been told. And the mayor just went on a lobbyist-funded fact-finding trip in the Bahamas. In the meantime, you got your hands on two national datasets: one on SAT scores by state, and one on drug use by age. Start exploring these to look for useful patterns and possible hypotheses!
#
# ---
#
# This project is focused on exploratory data analysis, aka "EDA". EDA is an essential part of the data science analysis pipeline. Failure to perform EDA before modeling is almost guaranteed to lead to bad models and faulty conclusions. What you do in this project are good practices for all projects going forward, especially those after this bootcamp!
#
# This lab includes a variety of plotting problems. Much of the plotting code will be left up to you to find either in the lecture notes, or if not there, online. There are massive amounts of code snippets either in documentation or sites like [Stack Overflow](https://stackoverflow.com/search?q=%5Bpython%5D+seaborn) that have almost certainly done what you are trying to do.
#
# **Get used to googling for code!** You will use it every single day as a data scientist, especially for visualization and plotting.
#
# #### Package imports

# %%
import numpy as np
import scipy.stats as stats
import csv
import pandas as pd
import seaborn as sns
import pprint
import matplotlib.pyplot as plt

# this line tells jupyter notebook to put the plots in the notebook rather than saving them to file.
# %matplotlib inline

# this line makes plots prettier on mac retina screens. If you don't have one it shouldn't do anything.
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 1. Load the `sat_scores.csv` dataset and describe it
#
# ---
#
# You should replace the placeholder path to the `sat_scores.csv` dataset below with your specific path to the file.
#
# ### 1.1 Load the file with the `csv` module and put it in a Python dictionary
#
# The dictionary format for data will be the column names as key, and the data under each column as the values.
#
# Toy example:
# ```python
# data = {
#     'column1':[0,1,2,3],
#     'column2':['a','b','c','d']
#     }
# ```

# %%
# Load CSV file for SATS Score
sat_score_path = './sat_scores.csv'

with open(sat_score_path, 'r') as f:
    rows_sat = [row for row in csv.reader(f)]
f.close()

# %%
# Show how does the data look like
rows_sat[0:5]
# Out:
# [['State', 'Rate', 'Verbal', 'Math'],
#  ['CT', '82', '509', '510'],
#  ['NJ', '81', '499', '513'],
#  ['MA', '79', '511', '515'],
#  ['NY', '77', '495', '505']]

# %%
# Separating Header and Data 
header = rows_sat[0]
data = rows_sat[1:]

# %%
# Create Dictionary with data 
sats_data = {header[i]: [row[i] for row in data ] for i in range(len(header))}

# %%
pprint.pprint(sats_data)
# Out:
# {'Math': ['510',
#           '513',
#           '515',
#           '505',
#           '516',
#           '499',
#           '499',
#           '506',
#           '500',
#           '501',
#           '499',
#           '510',
#           '499',
#           '489',
#           '501',
#           '488',
#           '474',
#           '526',
#           '499',
#           '527',
#           '499',
#           '515',
#           '510',
#           '517',
#           '525',
#           '515',
#           '542',
#           '439',
#           '539',
#           '512',
#           '542',
#           '553',
#           '542',
#           '589',
#           '550',
#           '545',
#           '572',
#           '589',
#           '580',
#           '554',
#           '568',
#           '561',
#           '577',
#           '562',
#           '596',
#           '550',
#           '570',
#           '603',
#           '582',
#           '599',
#           '551',
#           '514'],
# ...

# %% [markdown]
# ### 1.2 Make a pandas DataFrame object with the SAT dictionary, and another with the pandas `.read_csv()` function
#
# Compare the DataFrames using the `.dtypes` attribute in the DataFrame objects. What is the difference between loading from file and inputting this dictionary (if any)?

# %%
# Make Pandas DataFrame Object with SAT Dict 
sat_dict_df = pd.DataFrame(sats_data)
sat_dict_df.dtypes
# Out:
# Math      object
# Rate      object
# State     object
# Verbal    object
# dtype: object

# %%
# Make Pandas DataFrame 
sat_df = pd.read_csv(sat_score_path)
sat_df.sample(5)
# Out:
#    State  Rate  Verbal  Math
# 37    MN     9     580   589
# 12    NC    65     493   499
# 33    IL    12     576   589
# 40    NE     8     562   568
# 2     MA    79     511   515

# %%
sat_df.dtypes
# Out:
# State     object
# Rate       int64
# Verbal     int64
# Math       int64
# dtype: object

# %% [markdown]
# ### What is the difference between loading from file and inputting this dictionary (if any)?

# %%
# When we load data into a dataframe, the dataframe will automatically change the entries with 'x', where x is a numeric value into integers or float accordingly. 
# For dictionary, we'll have to manually change each entries into the type that we want.  

# To convert number data from string to float 
for head in header: 
    sats_data[head] = [int(val) if val[0].isdigit() == True
                       else val for val in sats_data[head]]
sat_dict_df = pd.DataFrame(sats_data)
sat_dict_df.dtypes
# Out:
# Math       int64
# Rate       int64
# State     object
# Verbal     int64
# dtype: object

# %% [markdown]
# ### 1.3 Look at the first ten rows of the DataFrame: what does our data describe?
#
# From now on, use the DataFrame loaded from the file using the `.read_csv()` function.
#
# Use the `.head(num)` built-in DataFrame function, where `num` is the number of rows to print out.
#
# You are not given a "codebook" with this data, so you will have to make some (very minor) inference.

# %%
sat_df.head(10)
# Out:
#   State  Rate  Verbal  Math
# 0    CT    82     509   510
# 1    NJ    81     499   513
# 2    MA    79     511   515
# 3    NY    77     495   505
# 4    NH    72     520   516
# 5    RI    71     501   499
# 6    PA    71     500   499
# 7    VT    69     511   506
# 8    ME    69     506   500
# 9    VA    68     510   501

# %%
sat_df.tail(10)
# Out:
#    State  Rate  Verbal  Math
# 42    MO     8     577   577
# 43    LA     7     564   562
# 44    WI     6     584   596
# 45    AR     6     562   550
# 46    UT     5     575   570
# 47    IA     5     593   603
# 48    SD     4     577   582
# 49    ND     4     592   599
# 50    MS     4     566   551
# 51   All    45     506   514

# %%
# There is an additional 'all' 
sat_df.drop(index = 51,inplace = True)

# %%
sat_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 4 columns):
# State     51 non-null object
# Rate      51 non-null int64
# Verbal    51 non-null int64
# Math      51 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 2.0+ KB

# %%
sat_df.describe(include = 'all')
# Out:
#        State       Rate      Verbal        Math
# count     51  51.000000   51.000000   51.000000
# unique    51        NaN         NaN         NaN
# top       SD        NaN         NaN         NaN
# freq       1        NaN         NaN         NaN
# mean     NaN  37.000000  532.529412  531.843137
# std      NaN  27.550681   33.360667   36.287393
# min      NaN   4.000000  482.000000  439.000000
# 25%      NaN   9.000000  501.000000  503.000000
# 50%      NaN  33.000000  527.000000  525.000000
# 75%      NaN  64.000000  562.000000  557.500000
# max      NaN  82.000000  593.000000  603.000000

# %%
# SAT is a standardized test used for college admissions
# Tells us the average score by state

# %%
description = {'State': 'Acronym that refers to the states of America.'\
               ,'Rate': 'Percentile of participation out of eligible candidates within the state'\
               ,'Verbal': 'Average score on Verbal section per state'\
               ,'Math': 'Average score on Math section per state'}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 2. Create a "data dictionary" based on the data
#
# ---
#
# A data dictionary is an object that describes your data. This should contain the name of each variable (column), the type of the variable, your description of what the variable is, and the shape (rows and columns) of the entire dataset.

# %%
def datadict(dataframe):
    print 'Data shape is {}'.format(dataframe.shape)
    for head in dataframe.columns:
        print "{}'s Description: {}".format(head,description[head])
        print "    Its type is {}".format(sat_df[head].dtype)

# %%
datadict(sat_df)
# Out:
# Data shape is (51, 4)
# State's Description: Acronym that refers to the states of America.
#     Its type is object
# Rate's Description: Percentile of participation out of eligible candidates within the state
#     Its type is int64
# Verbal's Description: Average score on Verbal section per state
#     Its type is int64
# Math's Description: Average score on Math section per state
#     Its type is int64

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 3. Plot the data using seaborn
#
# ---
#
# ### 3.1 Using seaborn's `distplot`, plot the distributions for each of `Rate`, `Math`, and `Verbal`
#
# Set the keyword argument `kde=False`. This way you can actually see the counts within bins. You can adjust the number of bins to your liking.
#
# [Please read over the `distplot` documentation to learn about the arguments and fine-tune your chart if you want.](https://stanford.edu/~mwaskom/software/seaborn/generated/seaborn.distplot.html#seaborn.distplot)

# %%
def dist_plot(dataframe,column):
    data = dataframe[column]
    #ensure that each figure do not overlap
    plt.figure() 
    #plot the graph 
    ax = sns.distplot(data,bins=50,kde=False)
    ax.set_title("Distribution of "+column)
    ax.set_ylabel("Qty")
    ax.set_xlabel("Score")

# %%
for col in ['Rate','Math','Verbal']:
    dist_plot(sat_df,col)

# %% [markdown]
# ### 3.2 Using seaborn's `pairplot`, show the joint distributions for each of `Rate`, `Math`, and `Verbal`
#
# Explain what the visualization tells you about your data.
#
# [Please read over the `pairplot` documentation to fine-tune your chart.](https://stanford.edu/~mwaskom/software/seaborn/generated/seaborn.pairplot.html#seaborn.pairplot)

# %%
sns.pairplot(sat_df)

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 4. Plot the data using built-in pandas functions.
#
# ---
#
# Pandas is very powerful and contains a variety of nice, built-in plotting functions for your data. Read the documentation here to understand the capabilities:
#
# http://pandas.pydata.org/pandas-docs/stable/visualization.html
#
# ### 4.1 Plot a stacked histogram with `Verbal` and `Math` using pandas

# %%
stacked_hist = sat_df[['Verbal','Math']].plot(kind='hist',stacked=True, bins = 20)
stacked_hist.set_title("Verbal VS Math Scores")
stacked_hist.set_xlabel("Score");
#possible to make it transparent

# %% [markdown]
# ### 4.2 Plot `Verbal` and `Math` on the same chart using boxplots
#
# What are the benefits of using a boxplot as compared to a scatterplot or a histogram?
#
# What's wrong with plotting a box-plot of `Rate` on the same chart as `Math` and `Verbal`? <br>
# <a id='boxplot'> </a>
# [Link to Qn 8](#Qn8) <br>

# %%
#using matplotlib
sat_df[['Verbal','Math']].plot(kind='box')

# %%
#using seaborn
box_plotv2 = sns.boxplot(data = sat_df[['Verbal','Math']]);
box_plotv2.set_title("Boxplot of Verbal and Math scores")
# Out:
# Text(0.5,1,u'Boxplot of Verbal and Math scores')

# %%
#Aside boxplot, we can also use violin plot to see distribution 
sns.violinplot(data = sat_df[['Verbal','Math']])

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 4.3 Plot `Verbal`, `Math`, and `Rate` appropriately on the same boxplot chart
#
# Think about how you might change the variables so that they would make sense on the same chart. Explain your rationale for the choices on the chart. You should strive to make the chart as intuitive as possible.

# %%
sns.boxplot(data = sat_df[['Rate','Verbal','Math']]);
# the data is skewed, so we must standardize

# %%
test_df = sat_df.copy()

# %%
def standardization(dataframe,col):
    data = dataframe[col]
    mean = np.mean(data)
    std = np.std(data)
    
    data = [(val-mean)/std for val in data]
    return data

# %%
for col in ['Math','Verbal','Rate']:
    test_df[col] = standardization(test_df,col)

# %%
test_df.sample(5)
# Out:
#    State      Rate    Verbal      Math
# 14    IN  0.843132 -1.015059 -0.858426
# 0     CT  1.649606 -0.712322 -0.607938
# 26    CO -0.219947  0.195889  0.282686
# 36    MI -0.953106  0.861910  1.117646
# 6     PA  1.246369 -0.984785 -0.914090

# %%
sns.boxplot(data = test_df[['Rate','Verbal','Math']]);

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 5. Create and examine subsets of the data
#
# ---
#
# For these questions you will practice **masking** in pandas. Masking uses conditional statements to select portions of your DataFrame (through boolean operations under the hood.)
#
# Remember the distinction between DataFrame indexing functions in pandas:
#
#     .iloc[row, col] : row and column are specified by index, which are integers
#     .loc[row, col]  : row and column are specified by string "labels" (boolean arrays are allowed; useful for rows)
#     .ix[row, col]   : row and column indexers can be a mix of labels and integer indices
#
# For detailed reference and tutorial make sure to read over the pandas documentation:
#
# http://pandas.pydata.org/pandas-docs/stable/indexing.html
#
#
#
# ### 5.1 Find the list of states that have `Verbal` scores greater than the average of `Verbal` scores across states
#
# How many states are above the mean? What does this tell you about the distribution of `Verbal` scores?

# %%
states_greater_than_mean = list(sat_df[sat_df['Verbal']>np.mean(sat_df['Verbal'])]['State'])
print "List of states that have Verbal Score > Mean: \n{}".format(states_greater_than_mean)
print "No. of States with Verbal Scores > Mean: {}".format(len(states_greater_than_mean))
print "Total no. of States: {}".format(len(sat_df['Verbal']))
# Out:
# List of states that have Verbal Score > Mean:
# ['CO', 'OH', 'MT', 'ID', 'TN', 'NM', 'IL', 'KY', 'WY', 'MI', 'MN', 'KS', 'AL', 'NE', 'OK', 'MO', 'LA', 'WI', 'AR', 'UT', 'IA', 'SD', 'ND', 'MS']
# No. of States with Verbal Scores > Mean: 24
# Total no. of States: 51

# %%
# Tells us that the Verbal scores distribution is slightly skewed

# %% [markdown]
# ### 5.2 Find the list of states that have `Verbal` scores greater than the median of `Verbal` scores across states
#
# How does this compare to the list of states greater than the mean of `Verbal` scores? Why?

# %%
states_greater_than_median = list(sat_df[sat_df['Verbal']>np.median(sat_df['Verbal'])]['State'])
print "List of states that have Verbal Score > Median: \n{}".format(states_greater_than_median)
print "No. of States with Verbal Scores > Median is {}".format(len(states_greater_than_median))
print "Total no. of States is {}".format(len(sat_df['Verbal']))
# Out:
# List of states that have Verbal Score > Median:
# ['CO', 'OH', 'MT', 'ID', 'TN', 'NM', 'IL', 'KY', 'WY', 'MI', 'MN', 'KS', 'AL', 'NE', 'OK', 'MO', 'LA', 'WI', 'AR', 'UT', 'IA', 'SD', 'ND', 'MS']
# No. of States with Verbal Scores > Median is 24
# Total no. of States is 51

# %%
# i.e. the national's average of Verbal SAT score is slightly higher than the median, it is right skewed
print 'Mean: ', np.mean(sat_df['Verbal'])
print 'Median: ', np.median(sat_df['Verbal'])
# Out:
# Mean:  532.529411765
# Median:  527.0

# %% [markdown]
# ### 5.3 Create a column that is the difference between the `Verbal` and `Math` scores
#
# Specifically, this should be `Verbal - Math`.

# %%
diff = sat_df['Verbal'] - sat_df['Math']

# %%
sat_df['Diff_VnM'] = diff
sat_df.sample(5)
# Out:
#    State  Rate  Verbal  Math  Diff_VnM
# 13    GA    63     491   489         2
# 49    ND     4     592   599        -7
# 21    HI    52     485   515       -30
# 44    WI     6     584   596       -12
# 0     CT    82     509   510        -1

# %% [markdown]
# ### 5.4 Create two new DataFrames showing states with the greatest difference between scores
#
# 1. Your first DataFrame should be the 10 states with the greatest gap between `Verbal` and `Math` scores where `Verbal` is greater than `Math`. It should be sorted appropriately to show the ranking of states.
# 2. Your second DataFrame will be the inverse: states with the greatest gap between `Verbal` and `Math` such that `Math` is greater than `Verbal`. Again, this should be sorted appropriately to show rank.
# 3. Print the header of both variables, only showing the top 3 states in each.

# %%
V_greater_M = sat_df.sort_values(by = 'Diff_VnM').head(10)
V_greater_M.index = range(1,11)
V_greater_M.head(3)
# Out:
#   State  Rate  Verbal  Math  Diff_VnM
# 1    HI    52     485   515       -30
# 2    CA    51     498   517       -19
# 3    NJ    81     499   513       -14

# %%
M_greater_V = sat_df.sort_values(by = 'Diff_VnM',ascending = False).head(10)
M_greater_V.index = range(1,11)
M_greater_V.head(3)
# Out:
#   State  Rate  Verbal  Math  Diff_VnM
# 1    OH    26     534   439        95
# 2    MS     4     566   551        15
# 3    WV    18     527   512        15

# %% [markdown]
# ## 6. Examine summary statistics
#
# ---
#
# Checking the summary statistics for data is an essential step in the EDA process!
#
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 6.1 Create the correlation matrix of your variables (excluding `State`).
#
# What does the correlation matrix tell you?

# %%
sat_df.corr()
# Out:
#               Rate    Verbal      Math  Diff_VnM
# Rate      1.000000 -0.888121 -0.773419 -0.098671
# Verbal   -0.888121  1.000000  0.899909  0.044527
# Math     -0.773419  0.899909  1.000000 -0.395574
# Diff_VnM -0.098671  0.044527 -0.395574  1.000000

# %%
# Tells us the following 
# 1. Correlation between Rate and Verbal and correlation between Rate and Verbal is negative
# 2. Correlation between Verbal and Math is positive. 
# 3. There is no correlation between the difference of the scores and the other variables.

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 6.2 Use pandas'  `.describe()` built-in function on your DataFrame
#
# Write up what each of the rows returned by the function indicate.

# %%
# include = 'all' includes string values
# count : counts the number of rows in the df 
# unique: counts the unique number of elements in the column. Returns NAN is continuous variable 
# top: 
# mean: average of the data set in the column
# std: standard deviation of the data set in the column
# min: smallest value of the data set in the column
# 25%: first quartile of the data set in the column
# 50%: median of the data set in the column
# 75%: third quartile of the data set in the column
# max%: largest value of the data set in the column
sat_df.describe(include = 'all')
# Out:
#        State       Rate      Verbal        Math   Diff_VnM
# count     51  51.000000   51.000000   51.000000  51.000000
# unique    51        NaN         NaN         NaN        NaN
# top       SD        NaN         NaN         NaN        NaN
# freq       1        NaN         NaN         NaN        NaN
# mean     NaN  37.000000  532.529412  531.843137   0.686275
# std      NaN  27.550681   33.360667   36.287393  15.839811
# min      NaN   4.000000  482.000000  439.000000 -30.000000
# 25%      NaN   9.000000  501.000000  503.000000  -6.000000
# 50%      NaN  33.000000  527.000000  525.000000   0.000000
# 75%      NaN  64.000000  562.000000  557.500000   4.500000
# max      NaN  82.000000  593.000000  603.000000  95.000000

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 6.3 Assign and print the _covariance_ matrix for the dataset
#
# 1. Describe how the covariance matrix is different from the correlation matrix.
# 2. What is the process to convert the covariance into the correlation?
# 3. Why is the correlation matrix preferred to the covariance matrix for examining relationships in your data?

# %%
sat_df.cov()
# Out:
#             Rate       Verbal         Math    Diff_VnM
# Rate      759.04  -816.280000  -773.220000  -43.060000
# Verbal   -816.28  1112.934118  1089.404706   23.529412
# Math     -773.22  1089.404706  1316.774902 -227.370196
# Diff_VnM  -43.06    23.529412  -227.370196  250.899608

# %% [markdown]
# ##### 1. Describe how the covariance matrix is different from the correlation matrix.

# %%
# Covariance is a measure of how much two random variables vary together.

# The formula is:Cov(X,Y) = Σ E((X-μ)E(Y-ν)) / n-1 
# where:
# X is a random variable
# E(X) = μ is the expected value (the mean) of the random variable X and
# E(Y) = ν is the expected value (the mean) of the random variable Y
# n = the number of items in the data set

# whereas the correlation matrix between sets of data is a measure of how well they are related.

# %% [markdown]
# ##### 2.What is the process to convert the covariance into the correlation?
#
# ##### $$ \text{covariance}(X, Y) = \sum_{i=1}^N \frac{(X - \bar{X})(Y - \bar{Y})}{N}$$
#
# To convert cov to correlation: to divide covariance by the product of the standard deviation of the two data sets
#
# ##### $$ \text{pearson correlation}\;r = cor(X, Y) =\frac{cov(X, Y)}{std(X)std(Y)}$$

# %% [markdown]
# ##### 3.Why is the correlation matrix preferred to the covariance matrix for examining relationships in your data?

# %%
# A large covariance can mean a strong relationship between variables except when you're comapring data set of different scales. 
# A weak covariance may be a strong relationship because it is in a different data set with different scales.
# Covariance can take on practically any number while a correlation is limited: -1 to +1.
# Because of it’s numerical limitations, correlation is more useful for determining how strong the relationship is between the two variables.
# Correlation isn’t affected by changes in the center (i.e. mean) or scale of the variables

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 7. Performing EDA on "drug use by age" data.
#
# ---
#
# You will now switch datasets to one with many more variables. This section of the project is more open-ended - use the techniques you practiced above!
#
# We'll work with the "drug-use-by-age.csv" data, sourced from and described here: https://github.com/fivethirtyeight/data/tree/master/drug-use-by-age.
#
# ### 7.1
#
# Load the data using pandas. Does this data require cleaning? Are variables missing? How will this affect your approach to EDA on the data?

# %%
#load the data into dataframe
drug = pd.read_csv('./drug-use-by-age.csv')

# %%
# This is how the data looks like 
drug.sample(5)
# Out:
#       age     n  alcohol-use  alcohol-frequency  marijuana-use  \
# 9      21  2354         83.2               52.0           33.0
# 10  22-23  4707         84.2               52.0           28.4
# 15  50-64  3923         67.2               52.0            7.3
# 14  35-49  7391         75.0               52.0           10.4
# 6      18  2469         58.7               24.0           33.7
#
#     marijuana-frequency  cocaine-use cocaine-frequency  crack-use  \
# 9                  52.0          4.8               5.0        0.5
# 10                 52.0          4.5               5.0        0.5
# 15                 52.0          0.9              36.0        0.4
# 14                 48.0          1.5              15.0        0.5
# 6                  52.0          3.2               5.0        0.4
#
#    crack-frequency        ...          oxycontin-use oxycontin-frequency  \
# 9             17.0        ...                    1.3                13.5
# ...

# %%
# There are 17 rows and 28 columns 
drug.shape
# Out:
# (17, 28)

# %%
#There are no null values
drug.isnull().sum()
# Out:
# age                        0
# n                          0
# alcohol-use                0
# alcohol-frequency          0
# marijuana-use              0
# marijuana-frequency        0
# cocaine-use                0
# cocaine-frequency          0
# crack-use                  0
# crack-frequency            0
# heroin-use                 0
# heroin-frequency           0
# hallucinogen-use           0
# hallucinogen-frequency     0
# inhalant-use               0
# inhalant-frequency         0
# pain-releiver-use          0
# pain-releiver-frequency    0
# oxycontin-use              0
# oxycontin-frequency        0
# tranquilizer-use           0
# tranquilizer-frequency     0
# stimulant-use              0
# stimulant-frequency        0
# meth-use                   0
# meth-frequency             0
# sedative-use               0
# sedative-frequency         0
# dtype: int64

# %%
drug.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 28 columns):
# age                        17 non-null object
# n                          17 non-null int64
# alcohol-use                17 non-null float64
# alcohol-frequency          17 non-null float64
# marijuana-use              17 non-null float64
# marijuana-frequency        17 non-null float64
# cocaine-use                17 non-null float64
# cocaine-frequency          17 non-null object
# crack-use                  17 non-null float64
# crack-frequency            17 non-null object
# heroin-use                 17 non-null float64
# heroin-frequency           17 non-null object
# hallucinogen-use           17 non-null float64
# hallucinogen-frequency     17 non-null float64
# inhalant-use               17 non-null float64
# inhalant-frequency         17 non-null object
# pain-releiver-use          17 non-null float64
# pain-releiver-frequency    17 non-null float64
# ...

# %%
# From the information above, these are the columns we should 'clean' 
# age                        17 non-null object --> should be int/float
# cocaine-frequency          17 non-null object  --> should be int/float
# crack-frequency            17 non-null object --> should be int/float
# heroin-frequency           17 non-null object --> should be int/float
# inhalant-frequency         17 non-null object --> should be int/float
# oxycontin-frequency        17 non-null object --> should be int/float
# meth-frequency             17 non-null object --> should be int/float

# %%
# Clean up age column 
drug['age'].unique
# Out:
# <bound method Series.unique of 0        12
# 1        13
# 2        14
# 3        15
# 4        16
# 5        17
# 6        18
# 7        19
# 8        20
# 9        21
# 10    22-23
# 11    24-25
# 12    26-29
# 13    30-34
# 14    35-49
# 15    50-64
# 16      65+
# Name: age, dtype: object>

# %%
# It turns out that the column 'age' is categorical instead.
# It doesn't make sense to split the values into the specific ages as they have been aggregated
# Conclusion: keep age as string object

# %%
for col in ['cocaine-frequency','crack-frequency','heroin-frequency','inhalant-frequency', 'oxycontin-frequency', 'meth-frequency']:
    print col
    print drug[col].unique(), '\n'
# Out:
# cocaine-frequency
# ['5.0' '1.0' '5.5' '4.0' '7.0' '8.0' '6.0' '15.0' '36.0' '-']
#
# crack-frequency
# ['-' '3.0' '9.5' '1.0' '21.0' '10.0' '2.0' '5.0' '17.0' '6.0' '15.0'
#  '48.0' '62.0']
#
# heroin-frequency
# ['35.5' '-' '2.0' '1.0' '66.5' '64.0' '46.0' '180.0' '45.0' '30.0' '57.5'
#  '88.0' '50.0' '66.0' '280.0' '41.0' '120.0']
#
# inhalant-frequency
# ['19.0' '12.0' '5.0' '5.5' '3.0' '4.0' '2.0' '3.5' '10.0' '13.5' '-']
#
# oxycontin-frequency
# ['24.5' '41.0' '4.5' '3.0' '4.0' '6.0' '7.0' '7.5' '12.0' '13.5' '17.5'
#  '20.0' '46.0' '5.0' '-']
#
# meth-frequency
# ['-' '5.0' '24.0' '10.5' '36.0' '48.0' '12.0' '105.0' '2.0' '46.0' '21.0'
#  '30.0' '54.0' '104.0']

# %%
# '-' are causing the data to become string objects

# %%
for col in ['cocaine-frequency','crack-frequency','heroin-frequency','inhalant-frequency', 'oxycontin-frequency', 'meth-frequency']:
    drug[col] = [0.0 if val == '-' else float(val) for val in drug[col]]

# %%
drug.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 28 columns):
# age                        17 non-null object
# n                          17 non-null int64
# alcohol-use                17 non-null float64
# alcohol-frequency          17 non-null float64
# marijuana-use              17 non-null float64
# marijuana-frequency        17 non-null float64
# cocaine-use                17 non-null float64
# cocaine-frequency          17 non-null float64
# crack-use                  17 non-null float64
# crack-frequency            17 non-null float64
# heroin-use                 17 non-null float64
# heroin-frequency           17 non-null float64
# hallucinogen-use           17 non-null float64
# hallucinogen-frequency     17 non-null float64
# inhalant-use               17 non-null float64
# inhalant-frequency         17 non-null float64
# pain-releiver-use          17 non-null float64
# pain-releiver-frequency    17 non-null float64
# ...

# %%
drug
# Out:
#       age     n  alcohol-use  alcohol-frequency  marijuana-use  \
# 0      12  2798          3.9                3.0            1.1
# 1      13  2757          8.5                6.0            3.4
# 2      14  2792         18.1                5.0            8.7
# 3      15  2956         29.2                6.0           14.5
# 4      16  3058         40.1               10.0           22.5
# 5      17  3038         49.3               13.0           28.0
# 6      18  2469         58.7               24.0           33.7
# 7      19  2223         64.6               36.0           33.4
# 8      20  2271         69.7               48.0           34.0
# 9      21  2354         83.2               52.0           33.0
# 10  22-23  4707         84.2               52.0           28.4
# 11  24-25  4591         83.1               52.0           24.9
# 12  26-29  2628         80.7               52.0           20.8
# 13  30-34  2864         77.5               52.0           16.4
# ...

# %%
# There are some data where there the drug usage=0 but frequency is not 0 
# inconsistent when we were cleaning the data earlier 
# There would be also be analysis on drug frequency
# Therefore, identify these values and set to 0 
for i in drug.index:
    for j,use in enumerate(drug.columns):
            if j%2 == 0 and drug.iloc[i,j] == 0 and drug.iloc[i,j+1] != 0:
                print drug.loc[i,'age'],drug.columns[j+1], drug.columns[j], drug.iloc[i,j+1]
# Out:
# 13 crack-frequency crack-use 3.0
# 16 crack-frequency crack-use 1.0
# 65+ heroin-frequency heroin-use 120.0
# 65+ stimulant-frequency stimulant-use 364.0
# 65+ sedative-frequency sedative-use 15.0

# %%
drug_df = drug.copy() #create a spare copy
for i in drug.index:
    for j,use in enumerate(drug.columns):
            if j%2 == 0 and drug.iloc[i,j] == 0 and drug.iloc[i,j+1] != 0:
                drug.iloc[i,j+1] = 0

# %%
drug
# Out:
#       age     n  alcohol-use  alcohol-frequency  marijuana-use  \
# 0      12  2798          3.9                3.0            1.1
# 1      13  2757          8.5                6.0            3.4
# 2      14  2792         18.1                5.0            8.7
# 3      15  2956         29.2                6.0           14.5
# 4      16  3058         40.1               10.0           22.5
# 5      17  3038         49.3               13.0           28.0
# 6      18  2469         58.7               24.0           33.7
# 7      19  2223         64.6               36.0           33.4
# 8      20  2271         69.7               48.0           34.0
# 9      21  2354         83.2               52.0           33.0
# 10  22-23  4707         84.2               52.0           28.4
# 11  24-25  4591         83.1               52.0           24.9
# 12  26-29  2628         80.7               52.0           20.8
# 13  30-34  2864         77.5               52.0           16.4
# ...

# %% [markdown]
# ### 7.2 Do a high-level, initial overview of the data
#
# Get a feel for what this dataset is all about.
#
# Use whichever techniques you'd like, including those from the SAT dataset EDA. The final response to this question should be a written description of what you infer about the dataset.
#
# Some things to consider doing:
#
# - Look for relationships between variables and subsets of those variables' values
# - Derive new features from the ones available to help your analysis
# - Visualize everything!

# %%
drug.describe()
# Out:
#                  n  alcohol-use  alcohol-frequency  marijuana-use  \
# count    17.000000    17.000000          17.000000      17.000000
# mean   3251.058824    55.429412          33.352941      18.923529
# std    1297.890426    26.878866          21.318833      11.959752
# min    2223.000000     3.900000           3.000000       1.100000
# 25%    2469.000000    40.100000          10.000000       8.700000
# 50%    2798.000000    64.600000          48.000000      20.800000
# 75%    3058.000000    77.500000          52.000000      28.400000
# max    7391.000000    84.200000          52.000000      34.000000
#
#        marijuana-frequency  cocaine-use  cocaine-frequency  crack-use  \
# count            17.000000    17.000000          17.000000  17.000000
# mean             42.941176     2.176471           7.411765   0.294118
# std              18.362566     1.816772           8.014119   0.235772
# min               4.000000     0.000000           0.000000   0.000000
# ...

# %%
#I want to compare all the drug-use variables and drug freq variables 
drug_use_col = list(drug.columns)[2::2]
drug_freq_col = list(drug.columns)[3::2]

# %%
drug_use_col
# Out:
# ['alcohol-use',
#  'marijuana-use',
#  'cocaine-use',
#  'crack-use',
#  'heroin-use',
#  'hallucinogen-use',
#  'inhalant-use',
#  'pain-releiver-use',
#  'oxycontin-use',
#  'tranquilizer-use',
#  'stimulant-use',
#  'meth-use',
#  'sedative-use']

# %%
drug[['age'] + drug_freq_col].set_index('age').plot(figsize=(12,8))
plt.legend(loc='upper right', bbox_to_anchor=(1.3,1))
plt.xticks(range(0,18), list(drug['age']))
plt.title('Drug Frequency');

# %%
# Additional Note: possibly to split into age categories for clearer comparison 
drug[['age'] + drug_freq_col].set_index('age').plot(figsize=(12,8))
plt.legend(loc='upper right', bbox_to_anchor=(1.3,1))
plt.xticks(range(0,18), list(drug['age']))
plt.title('Drug Frequency');

# %%
#standardize
drug_freq = drug[['age'] + drug_freq_col].set_index('age')
for col in drug_freq.columns:
    data = drug_freq[col].values
    data_mean = np.mean(data)
    data_std = np.std(data)
    data_stand = (data - data_mean) / data_std
    drug_freq[col] = data_stand

# %%
drug_freq.plot(figsize=(12,8))
plt.legend(loc='upper right', bbox_to_anchor=(1.3,1))
plt.xticks(range(0,18), list(drug['age']))
plt.title('Drug Frequency');

# %%
# From the graph above, it can be see that the general trend is as such: 
# There is a high drug abuse at age 12. 
# there is a spike at age 19 --> which is generally the age of consent 
# there is another spike for different drugs between age 30-64.

# %%
# Want to see the relationship between the drug usage and it's frequency. 
for i in range(len(drug_use_col)):
    #Set the plot figure + Title 
    fig,axes = plt.subplots(nrows=1,ncols=2,figsize = (12,4))
    plt.suptitle('{} vs {}'.format(drug_use_col[i],drug_freq_col[i]))
    
    # Plot the correlation heat map on the left subplot 
    sns.heatmap(drug[[drug_use_col[i],drug_freq_col[i]]].corr(),annot=True,vmin=-1.,vmax=1.,ax=axes[0])
    
    #to define round up function to define the axis  
    def roundup(x):
        return int(np.ceil(x/10.))*10
    
    # Plot the trend across the ages on the right subplot 
    drug[['age',drug_use_col[i]]].set_index('age').plot(kind='bar',ax=axes[1])
    ax3 = axes[1].twinx()   # instantiate a second axes that shares the same x-axis
    axes[1].legend(loc='upper left', bbox_to_anchor=(1.3,1))
    
    drug[['age',drug_freq_col[i]]].set_index('age').plot(ax=ax3,color='r')
    ax3.set_ylim([0, roundup(max(drug[drug_freq_col[i]]))]) #reset seconday y axis
    ax3.legend(loc='upper left', bbox_to_anchor=(1.3,1.1))

# %%
subplot_index
# Out:
# [(0, 0),
#  (0, 1),
#  (0, 2),
#  (0, 3),
#  (0, 4),
#  (1, 0),
#  (1, 1),
#  (1, 2),
#  (1, 3),
#  (1, 4),
#  (2, 0),
#  (2, 1),
#  (2, 2),
#  (2, 3),
#  (2, 4)]

# %%
# Obsevations: 
# - Only Alcohol-use and Alcohol frequency have a strong correlation. The others do not have. 
# - For most drugs, there is a spike of drug frequency at 12/13 years old and in the 50-64 years old of age 
#   that has no correlation with it's drug use (includes ) 
# - There is a large spike at age 19 for Meth-frequency and heroin-frequency 
# - Frequency of Marijuana increases with age and maintains after 35 years old 
# - Frequency of alcohol frequency increases until age 21 and maintains at that frequency.

# %%
plt.figure(figsize = (10,8))
plt.title('Correlation Matrix of Drug Frequencies')

sns.heatmap(drug[drug_freq_col].corr(),annot=True);

# %%
plt.figure(figsize = (8,8))
plt.title('Correlation between drug use',fontsize = 16)
sns.heatmap(drug[drug_use_col].corr(),annot=True,vmin=-1.,vmax=1.);

# %%
# From the heat map, there are these are the observation: 
# 1. inhalant-use and sedative-use do not have correlation with the other variables as their values tend to 0
# 2. Other variables tend to have a strong correlation with each other 
# 3. In particular, ['oxycontin-use', 'pain-releiver-use', 'marijuana-use', 'stimulant-use', 'hallucinogen-use', 'tranquilizer-use']
#    have the strongest correlation relationship. (see the numbers below)

# %%
# Find the variables with the highest correlation
# Since max val is 0.97 and min val is -0.64, there is not need to find the absolute correlation value for comparison.
# Below are the top 10 
sorted([(np.corrcoef(drug[i], drug[j])[0,1],i,j) 
         for i in drug_use_col for j in drug_use_col if i != j],reverse = True)[:20:2]
# Out:
# [(0.9764446814654528, 'oxycontin-use', 'pain-releiver-use'),
#  (0.9717329769163842, 'marijuana-use', 'oxycontin-use'),
#  (0.9680961763729243, 'stimulant-use', 'marijuana-use'),
#  (0.966225865412987, 'pain-releiver-use', 'marijuana-use'),
#  (0.9614837481931762, 'stimulant-use', 'pain-releiver-use'),
#  (0.9593526145599981, 'marijuana-use', 'hallucinogen-use'),
#  (0.9592832360684839, 'tranquilizer-use', 'pain-releiver-use'),
#  (0.9550806511348201, 'tranquilizer-use', 'oxycontin-use'),
#  (0.947491778554425, 'stimulant-use', 'oxycontin-use'),
#  (0.9400078070491579, 'stimulant-use', 'hallucinogen-use')]

# %%
# Additional notes and further analysis: 
# There is no differentiation between good drugs and bad drugs --> possible to split the analysis between  
# Instead of using the data directly, we find percentile (frequency / n)

# %% [markdown]
# ### 7.3 Create a testable hypothesis about this data
#
# Requirements for the question:
#
# 1. Write a specific question you would like to answer with the data (that can be accomplished with EDA).
# 2. Write a description of the "deliverables": what will you report after testing/examining your hypothesis?
# 3. Use EDA techniques of your choice, numeric and/or visual, to look into your question.
# 4. Write up your report on what you have found regarding the hypothesis about the data you came up with.
#
#
# Your hypothesis could be on:
#
# - Difference of group means
# - Correlations between variables
# - Anything else you think is interesting, testable, and meaningful!
#
# **Important notes:**
#
# You should be only doing EDA _relevant to your question_ here. It is easy to go down rabbit holes trying to look at every facet of your data, and so we want you to get in the practice of specifying a hypothesis you are interested in first and scoping your work to specifically answer that question.
#
# Some of you may want to jump ahead to "modeling" data to answer your question. This is a topic addressed in the next project and **you should not do this for this project.** We specifically want you to not do modeling to emphasize the importance of performing EDA _before_ you jump to statistical analysis.

# %% [markdown]
# ** Question and deliverables**
#
# I want to find out if the mean of drug frequency is statistically same for youths and adults.
# Youths in USA are defined as aged 25 and below
# Choose marijuana-frequency first.
#
# H0 = The difference in Marijuana Frequency between youths and adults is 0 <br>
# H1 = The difference in Marijuana Frequency between youths and adults is not 0

# %%
marijuana_youths = drug.iloc[:12]['marijuana-frequency']
marijuana_adults = drug.iloc[13:]['marijuana-frequency']

# %%
print 'Mean of marijuana_youths :', np.mean(marijuana_youths)
print 'Mean of marijuana_adults :', np.mean(marijuana_adults)
print '     Measured difference :', np.mean(marijuana_youths) - np.mean(marijuana_adults)
# Out:
# Mean of marijuana_youths : 39.1666666667
# Mean of marijuana_adults : 52.0
#      Measured difference : -12.8333333333

# %%
# simply use ttest 
t_stat,p_val = stats.ttest_ind(marijuana_youths,marijuana_adults)
df = len(marijuana_adults) + len(marijuana_youths) - 2

# %%
print t_stat
print p_val
print df
# Out:
# -1.1987430806222812
# 0.25052582762354286
# 14

# %%
# Visualizing the T-statistic 
xpoints = np.linspace(-4, 4, 500)
ypoints = stats.t.pdf(xpoints, df, 0, 1)

fig = plt.figure(figsize=(8,5))
ax = fig.gca()
ax.plot(xpoints, ypoints, linewidth=3, color='darkred')
ax.axvline(t_stat, color='black', linestyle='-', lw=5)
# confidence level at 95% 
ax.axvline(2.1448, color='blue', linestyle='--', lw=3)
ax.axvline(-2.1448, color='blue', linestyle='--', lw=3)

# %%
# Since p-value is bigger than the 0.025 (2 tail test)
# Therefore we cannot reject the null hypothesis that 
# The difference in Marijuana Frequency between youths and adults is 0 
# However, sample size very small + do not follow normal distribution

# %%
def bootstrap(sample, stat_func, iters=1000):
    boots = []
    for i in range(iters):
        random_sample = np.random.choice(sample, replace=True, size=len(sample))
        stat = stat_func(random_sample)
        boots.append(stat)
    return boots

# %%
marijuana_adults_boots = bootstrap(marijuana_adults, np.mean, iters=1000)

# %%
marijuana_youths_boots = bootstrap(marijuana_youths, np.mean, iters=1000)

# %%
mean_diff = pd.Series(marijuana_youths_boots) - pd.Series(marijuana_adults_boots)

# %%
# use t-test on 
t_stat,p_val = stats.ttest_ind(marijuana_youths_boots,marijuana_adults_boots)

# %%
print t_stat
print p_val
print df
# Out:
# -47.820918733477455
# 0.0
# 14

# %%
# Reject Null hypthesis 
# The difference in Marijuana Frequency between youths and adults is not 0

# %%
plt.figure(figsize = (12,8))
ax = sns.distplot(mean_diff, bins=50, kde=False)
plt.title('Distribution of difference in bootstrapped means',fontsize = 14);

# %% [markdown]
# **Report**
# cannot use t-test because sample size not large enough
# use bootstrapping instead
# p < 0. 05
# Reject Null hypthesis
# The difference in Marijuana Frequency between youths and adults is not 0

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 8. Introduction to dealing with outliers
#
# ---
#
# Outliers are an interesting problem in statistics, in that there is not an agreed upon best way to define them. Subjectivity in selecting and analyzing data is a problem that will recur throughout the course.
#
# 1. Pull out the rate variable from the sat dataset.
# 2. Are there outliers in the dataset? Define, in words, how you _numerically define outliers._
# 3. Print out the outliers in the dataset.
# 4. Remove the outliers from the dataset.
# 5. Compare the mean, median, and standard deviation of the "cleaned" data without outliers to the original. What is different about them and why?

# %%
# 1. Pull out the rate variable from the sat dataset.
sat_rate = sat_df.loc[:,['State','Rate']]

# %%
# 2. Are there outliers in the dataset? Define, in words, how you _numerically define outliers._
sns.distplot(sat_df['Rate'],bins=20)

# %%
fig = plt.figure(figsize=(4,8))
ax = fig.gca()
ax = sns.boxplot(sat_rate['Rate'], orient='v',
                fliersize=8, linewidth=1.5, notch=True,
                saturation=0.5, ax=ax)
ax.set_ylabel('Sat Rate', fontsize=16)
ax.set_title('SAT Rate boxplot\n', fontsize=20)

plt.show()

# %%
# From the 2 graphs, we can see that there is no outliers for Rate

# %% [markdown]
# <a id='Qn8'> </a>
# In the questions above, the box plot of Rate, Verbal and Math data has been plotted. There are no outliers.
# [Link to boxplot](#boxplot) <br>

# %%
# A convenient definition of a outlier is a point which falls more than 1.5 times the interquartile range above the third quartile or below the first quartile
def find_outlier(data):
    data_min = np.percentile(data,0)
    firstQ = np.percentile(data,25)
    thirdQ = np.percentile(data,75)
    data_max = np.percentile(data,100)
    IQR = thirdQ-firstQ
    outlier_left = firstQ-1.5*IQR
    outlier_right = thirdQ+1.5*IQR
    print data.name
    print ' min: ', data_min
    print ' 25%: ', firstQ
    print ' 50%: ', np.percentile(data,50)
    print ' 75%: ', thirdQ
    print ' max: ', data_max
    print ' IQR: ', IQR
    print 'Outlier range is <{} or >{}'.format(outlier_left,outlier_right)
    if data_min < outlier_left or data_max > outlier_right:
        print 'There are outliers! \n'
    else:
        print 'There are no outliers \n'

# %%
for col in ['Rate','Verbal','Math','Diff_VnM']:
    find_outlier(sat_df.iloc[0:51][col])
# Out:
# Rate
#  min:  4.0
#  25%:  9.0
#  50%:  33.0
#  75%:  64.0
#  max:  82.0
#  IQR:  55.0
# Outlier range is <-73.5 or >146.5
# There are no outliers
#
# Verbal
#  min:  482.0
#  25%:  501.0
#  50%:  527.0
#  75%:  562.0
#  max:  593.0
#  IQR:  61.0
# Outlier range is <409.5 or >653.5
# There are no outliers
#
# Math
#  min:  439.0
#  25%:  503.0
#  50%:  525.0
#  75%:  557.5
#  max:  603.0
#  IQR:  54.5
# Outlier range is <421.25 or >639.25
# There are no outliers
#
# Diff_VnM
#  min:  -30.0
#  25%:  -6.0
#  50%:  0.0
#  75%:  4.5
#  max:  95.0
#  IQR:  10.5
# Outlier range is <-21.75 or >20.25
# There are outliers!

# %%
sns.regplot(sat_df['Verbal'],sat_df['Math'],fit_reg=False)

# %%
sns.boxplot(sat_df['Diff_VnM'])

# %%
# From the data and graph, there are 2 outliers
# 3. Print out the outliers in the dataset.
outlier_i = []
for i,val in enumerate(sat_df['Diff_VnM']):
    data = sat_df['Diff_VnM']
    data_min = np.percentile(data,0)
    firstQ = np.percentile(data,25)
    thirdQ = np.percentile(data,75)
    data_max = np.percentile(data,100)
    IQR = thirdQ-firstQ
    outlier_left = firstQ-1.5*IQR
    outlier_right = thirdQ+1.5*IQR
    if val < outlier_left or val > outlier_right:
        print sat_df.iloc[i]
# Out:
# State        HI
# Rate         52
# Verbal      485
# Math        515
# Diff_VnM    -30
# Name: 21, dtype: object
# State        OH
# Rate         26
# Verbal      534
# Math        439
# Diff_VnM     95
# Name: 27, dtype: object

# %%
# 4. Remove the outliers from the dataset.
sat_no_outlier = sat_df.drop(index=[21,27])

# %%
# 5. Compare the mean, median, and standard deviation of the "cleaned" data without outliers to the original. What is different about them and why?
sat_no_outlier.describe(include='all').iloc[[4,5,8]]
# Out:
#      State       Rate      Verbal        Math  Diff_VnM
# mean   NaN  36.918367  533.469388  534.081633 -0.612245
# std    NaN  27.990204   33.336105   34.366188  7.395991
# 50%    NaN  33.000000  527.000000  526.000000  0.000000

# %%
sat_df.describe(include='all').iloc[[4,5,8]]
# Out:
#      State       Rate      Verbal        Math   Diff_VnM
# mean   NaN  37.000000  532.529412  531.843137   0.686275
# std    NaN  27.550681   33.360667   36.287393  15.839811
# 50%    NaN  33.000000  527.000000  525.000000   0.000000

# %%
# For all data, the mean increased while standard deviation decreased 
# decrease in standard deviation is due to eliminating the outlier point. so all data points are more congregated within an area
# Mean increases because the point eliminated scored worse than everyone else.

# %% [markdown]
# <img src="http://imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 9. Percentile scoring and spearman rank correlation
#
# ---
#
# ### 9.1 Calculate the spearman correlation of sat `Verbal` and `Math`
#
# 1. How does the spearman correlation compare to the pearson correlation?
# 2. Describe clearly in words the process of calculating the spearman rank correlation.
#   - Hint: the word "rank" is in the name of the process for a reason!

# %%
# Spearman's rank correlation coefficient can be defined as a special case of Pearson ρ applied to ranked (sorted) variables. 
# Unlike Pearson, Spearman's correlation is not restricted to linear relationships. 
# Instead, it measures monotonic association (only strictly increasing or decreasing, but not mixed) between two variables 
# and relies on the rank order of values. In other words, rather than comparing means and variances, 
# Spearman's coefficient looks at the relative order of values for each variable. 
# This makes it appropriate to use with both continuous and discrete data.

# %%
spearman = sat_df[['Rate','Verbal','Math']].corr(method='spearman')
spearman
# Out:
#             Rate    Verbal      Math
# Rate    1.000000 -0.836058 -0.811662
# Verbal -0.836058  1.000000  0.909413
# Math   -0.811662  0.909413  1.000000

# %%
pearson = sat_df[['Rate','Verbal','Math']].corr(method='pearson')
pearson
# Out:
#             Rate    Verbal      Math
# Rate    1.000000 -0.888121 -0.773419
# Verbal -0.888121  1.000000  0.899909
# Math   -0.773419  0.899909  1.000000

# %%
abs(spearman - pearson)
# Out:
#             Rate    Verbal      Math
# Rate    0.000000  0.052063  0.038242
# Verbal  0.052063  0.000000  0.009503
# Math    0.038242  0.009503  0.000000

# %% [markdown]
# ### 9.2 Percentile scoring
#
# Look up percentile scoring of data. In other words, the conversion of numeric data to their equivalent percentile scores.
#
# http://docs.scipy.org/doc/numpy-dev/reference/generated/numpy.percentile.html
#
# http://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.percentileofscore.html
#
# 1. Convert `Rate` to percentiles in the sat scores as a new column.
# 2. Show the percentile of California in `Rate`.
# 3. How is percentile related to the spearman rank correlation?

# %%
sat_df['Rate_%'] = [stats.percentileofscore(sat_df['Rate'], val, kind='rank') for val in sat_df['Rate']]

# %%
sat_df[sat_df['State'] == 'CA']
# Out:
#    State  Rate  Verbal  Math  Diff_VnM     Rate_%
# 23    CA    51     498   517       -19  55.882353

# %%
#Counting percentile is also a form of determining ranks of a dataset

# %% [markdown]
# ### 9.3 Percentiles and outliers
#
# 1. Why might percentile scoring be useful for dealing with outliers?
# 2. Plot the distribution of a variable of your choice from the drug use dataset.
# 3. Plot the same variable but percentile scored.
# 4. Describe the effect, visually, of coverting raw scores to percentile.

# %%
cocaine_df = drug[['age','cocaine-frequency']]

# %%
cocaine_df['cocaine-freq_%'] = [stats.percentileofscore(cocaine_df['cocaine-frequency'], val, kind='rank') for val in cocaine_df['cocaine-frequency']]
cocaine_df
# Out:
# C:\Users\ngyen\Anaconda2python2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#       age  cocaine-frequency  cocaine-freq_%
# 0      12                5.0       38.235294
# 1      13                1.0       11.764706
# 2      14                5.5       61.764706
# 3      15                4.0       17.647059
# 4      16                7.0       76.470588
# 5      17                5.0       38.235294
# 6      18                5.0       38.235294
# 7      19                5.5       61.764706
# 8      20                8.0       85.294118
# 9      21                5.0       38.235294
# 10  22-23                5.0       38.235294
# ...

# %%
drug[['age','cocaine-frequency']].plot()

# %%
cocaine_df.sort_values(by='cocaine-freq_%',inplace=True)
# Out:
# C:\Users\ngyen\Anaconda2python2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(cocaine_df['cocaine-freq_%'],cocaine_df['cocaine-frequency'])
